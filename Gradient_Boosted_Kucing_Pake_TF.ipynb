# %% [markdown]
# <a href="https://colab.research.google.com/github/ihsankarim/purrsonalcat/blob/main/Gradient_Boosted_Kucing_Pake_TF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow tensorflow_decision_forests

# %%
# !pip install tensorflow tensorflow_decision_forests 'tensorflowjs>=4.4.0'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 1.5 MB/s eta 0:00:00
# ...

# %%
# !pip install tensorflow

# %%
import tensorflow_decision_forests as tfdf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from google.colab import files

# %%
uploaded = files.upload()
data = pd.read_csv("Dummy.csv")
print(data.head())
# Out:
#      <input type="file" id="files-5a58edcd-a563-4d45-9ec1-a8be688d3225" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a58edcd-a563-4d45-9ec1-a8be688d3225">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Buat Cek Aja
print(data.columns)
# Out:
# Index(['ID', 'Batuk ', 'Bau mulut',
#        'Benjolan atau pembengkakan yang tidak hilang', 'Bersin',
#        'Borok di Lidah, Gusi, Bibir, atau Hidung', 'Buang Air kecil berlebih',
#        'Buang Air Besar Berlebih', 'Bulu rontok', 'Darah dalam urin',
#        'Dehidrasi', 'Demam', 'Diare', 'Gusi Bengkak',
#        'Gusi Merah atau Keunguan', 'Gusi Pucat', 'Infeksi saluran kemih',
#        'Infeksi Kulit', 'Infeksi telinga', 'Infertilitas (Mandul)',
#        'Kejang-kejang', 'Kesulitan buang air besar', 'Kesulitan Bernafas',
#        'Kemerahan', 'Kulit bersisik atau menglupas', 'Kulit Warna Kuning',
#        'Konjugtivitas (keluaran kuning pada mata)', 'Kulit berkerak',
#        'Kurang Nafsu Makan', 'Lecet', 'Lemes atau Lemah (Lethargy)',
#        'Luka yang tidak sembuh', 'Mata Berair', 'Muntah', 'Minum air lebih',
#        'Pembengkakan', 'Pembengkakan Kelenjar Getah Bening',
#        'Penurunan Berat Badan', 'Perut Kembung atau Membucit',
# ...

# %%
gejala_columns = data.columns[1:-1]
label_column = data.columns[-1]

# %%
#Train data
test_size = 0.15
train_features, test_features, train_labels, test_labels = train_test_split(
    features, labels, test_size=test_size, random_state=122
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-db704a7202f9> in <cell line: 3>()
#       2 test_size = 0.15
#       3 train_features, test_features, train_labels, test_labels = train_test_split(
# ----> 4     features, labels, test_size=test_size, random_state=122
#       5 )
#
# NameError: name 'features' is not defined

# %%
train_features[label_column] = train_labels
test_features[label_column] = test_labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-eb4c2b864534> in <cell line: 1>()
# ----> 1 train_features[label_column] = train_labels
#       2 test_features[label_column] = test_labels
#
# NameError: name 'train_labels' is not defined

# %%
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_features, label=label_column)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_features, label=label_column)
# Out:
# ...
# WARNING:absl:Some of the feature names have been changed automatically to be compatible with SavedModels because fix_feature_names=True.
# ...
# WARNING:absl:Some of the feature names have been changed automatically to be compatible with SavedModels because fix_feature_names=True.

# %%
#Model
model = tfdf.keras.GradientBoostedTreesModel(task=tfdf.keras.Task.CLASSIFICATION)
history = model.fit(train_ds)

model.summary()

#Evaluate model.
model.evaluate(test_ds)
print(model.evaluate(test_ds))

evaluation_result = model.evaluate(test_ds)
accuracy = evaluation_result
# Out:
# Use /tmp/tmp5tub33f0 as temporary training directory
# Reading training dataset...
# WARNING:tensorflow:6 out of the last 6 calls to <function CoreModel._consumes_training_examples_until_eof at 0x7a976b807d00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training dataset read in 0:00:01.346615. Found 214 examples.
# Training model...
# ---------------------------------------------------------------------------
# ...

# %%
tfdf.model_plotter.plot_model_in_colab(model, tree_idx=15)
# Out:
# <script src="https://d3js.org/d3.v6.min.js"></script>
# <div id="tree_plot_22d0173f211e40248a9188a16e0f8b37"></div>
# <script>
# /*
#  * Copyright 2021 Google LLC.
#  * Licensed under the Apache License, Version 2.0 (the "License");
#  * you may not use this file except in compliance with the License.
#  * You may obtain a copy of the License at
#  *
#  *     https://www.apache.org/licenses/LICENSE-2.0
#  *
#  * Unless required by applicable law or agreed to in writing, software
#  * distributed under the License is distributed on an "AS IS" BASIS,
#  * WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#  * See the License for the specific language governing permissions and
#  * limitations under the License.
#  */
#
# /**
#  *  Plotting of decision trees generated by TF-DF.
#  *
#  *  A tree is a recursive structure of node objects.
#  *  A node contains one or more of the following components:
#  *
# ...

# %%
model.save("/tmp/my_saved_model")

# Convert the Keras model to TensorFlow.js format
tfjs.converters.tf_saved_model_conversion_v2.convert_keras_model_to_graph_model(
    "/tmp/my_saved_model", "./tfjs_model"
)

# Zip the TensorFlow.js model
# !zip -r tfjs_model.zip tfjs_model/

# Download the converted TFJS model
files.download("tfjs_model.zip")
# Out:
# WARNING:tensorflow:`Infertilitas_(Mandul)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Konjugtivitas_(keluaran_kuning_pada_mata)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Lemes_atau_Lemah_(Lethargy)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Infertilitas_(Mandul)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Konjugtivitas_(keluaran_kuning_pada_mata)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Lemes_atau_Lemah_(Lethargy)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# ...

# %%
# Menampilkan grafik pelatihan tapi belum kelar
plt.figure(figsize=(12, 6))

# Plot lossnya
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot akurasinya
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model_json = model.to_json()

# Save model ke JSON file
with open("model_GradientBoost.json", "w") as json_file:
    json_file.write(model_json)

# Download jadi JSON file
files.download('model_GradientBoost.json')

# Save model weightsnya
model.save_weights('model_weights.h5')

files.download('model_weights.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6321d6b983c2> in <cell line: 1>()
# ----> 1 model_json = model.to_json()
#       2
#       3 # Save model ke JSON file
#       4 with open("model_GradientBoost.json", "w") as json_file:
#       5     json_file.write(model_json)
#
# NameError: name 'model' is not defined

# %%
import joblib
joblib.dump(model, 'model_GradientBoosted_TF.h5')
files.download('model_GradientBoosted_TF.h5')
